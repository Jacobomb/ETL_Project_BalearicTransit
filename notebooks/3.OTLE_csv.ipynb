# %% [markdown]
# #### OTLE
#
# Este notebook sirve para tener un preview del fichero CSV obtenido del Observatorio de Transporte y Logística de España (OTLE).
#
# Se ha descargado el archivo csv en el siguiente [link](https://apps.fomento.gob.es/BDOTLE/visorBDpop.aspx?i=328), bajo el siguiente título: *Tráfico de mercancía y pasaje en puertos de interés general (número de buques y GT) por Autoridad Portuaria, tipo de buque y nacionalidad*

# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('../data/Num_buques_GT_Tipo_Buque.csv')
df.head()
# Out:
#             autoridad_portuaria tipo_buque  procedencia  year  num_buques  \
# 0  Autoridad Portuaria A Coruña  Tanqueros   Nacionales  2019         3.0
# 1  Autoridad Portuaria A Coruña  Tanqueros   Nacionales  2020         4.0
# 2  Autoridad Portuaria A Coruña  Tanqueros   Nacionales  2021         1.0
# 3  Autoridad Portuaria A Coruña  Tanqueros  Extranjeros  2019       424.0
# 4  Autoridad Portuaria A Coruña  Tanqueros  Extranjeros  2020       287.0
#
#           gt           Textbox16  Textbox18  Textbox19            Textbox21  \
# 0     54.468  Subtotal tanqueros      427.0  9.527.266  Total A.P. A Coruña
# 1     21.696  Subtotal tanqueros      291.0  7.266.674  Total A.P. A Coruña
# 2      5.424  Subtotal tanqueros      381.0  8.438.750  Total A.P. A Coruña
# 3  9.472.798  Subtotal tanqueros      427.0  9.527.266  Total A.P. A Coruña
# 4  7.244.978  Subtotal tanqueros      291.0  7.266.674  Total A.P. A Coruña
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1176 entries, 0 to 1175
# Data columns (total 64 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   autoridad_portuaria  1176 non-null   object
#  1   tipo_buque           1176 non-null   object
#  2   procedencia          1176 non-null   object
#  3   year                 1176 non-null   int64
#  4   num_buques           1113 non-null   float64
#  5   gt                   1113 non-null   object
#  6   Textbox16            1176 non-null   object
#  7   Textbox18            1158 non-null   float64
#  8   Textbox19            1158 non-null   object
#  9   Textbox21            1176 non-null   object
#  10  Textbox113           1176 non-null   float64
#  11  Textbox116           1176 non-null   object
#  12  Textbox115           1176 non-null   float64
#  13  Textbox120           1176 non-null   object
#  14  Textbox66            1176 non-null   float64
# ...

# %% [markdown]
# Tomando algo de detalle a las columnas desde la 'gt' en adelante y al [link](https://apps.fomento.gob.es/BDOTLE/visorBDpop.aspx?i=328) de la fuente se puede proceder a borrar todas estas columnas. Pasar a renombrarlo es un proceso lento y que cobra poco sentido cuando con simples queries se pueden hallar los sumatorios de campos previos.

# %%
df = df.iloc[:, :6]
df.head()
# Out:
#             autoridad_portuaria tipo_buque  procedencia  year  num_buques  \
# 0  Autoridad Portuaria A Coruña  Tanqueros   Nacionales  2019         3.0
# 1  Autoridad Portuaria A Coruña  Tanqueros   Nacionales  2020         4.0
# 2  Autoridad Portuaria A Coruña  Tanqueros   Nacionales  2021         1.0
# 3  Autoridad Portuaria A Coruña  Tanqueros  Extranjeros  2019       424.0
# 4  Autoridad Portuaria A Coruña  Tanqueros  Extranjeros  2020       287.0
#
#           gt
# 0     54.468
# 1     21.696
# 2      5.424
# 3  9.472.798
# 4  7.244.978

# %%
df.to_csv('../data/otle_gt.csv', index=True)

# %% [markdown]
# Pasamos el nuevo y limpio dataframe a csv con título **otle_gt.csv**. Después de este paso podemos crear el entorno de la base de datos en SQL y posteriormente cargar las tablas con el contenido de dichos csv's.
